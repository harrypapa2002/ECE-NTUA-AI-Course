# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Αντώνιος Αλεξιάδης 03120167
#
# Στοιχεία Μέλους 2: Χαρίδημος Παπαδάκης 03120022

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('/content/drive/My Drive')

# %%
movies_filename = '/content/drive/My Drive/' + 'movies_metadata.csv'

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
path = '/content/drive/MyDrive/'
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))

  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")

  director_name = clean_text(getattr(row, 'director_name'))
  literals.append("director('"+ movie_title +"','"+ director_name +"')")
    
    
  #single quote in strings such as 'women's prison',  is being interpreted as the end of the string instead of part of the string
  #To fix this error, we replace it by the emtpy string
  for plot_keyword in getattr(row, 'plot_keywords').split("|"):
    plot_keyword = clean_text(plot_keyword)
    literals.append("plot_keyword('"+ movie_title +"','"+ plot_keyword +"')")

  actor_1_name = clean_text(getattr(row, 'actor_1_name'))
  literals.append("actor('"+ movie_title +"','"+ actor_1_name +"')")

  actor_2_name = clean_text(getattr(row, 'actor_2_name'))
  literals.append("actor('"+ movie_title +"','"+ actor_2_name +"')")

  actor_3_name = clean_text(getattr(row, 'actor_3_name'))
  literals.append("actor('"+ movie_title +"','"+ actor_3_name +"')")

  language = clean_text(getattr(row, 'language'))
  literals.append("language('"+ movie_title +"','"+ language + "')")

  if 'black and white' in getattr(row, 'plot_keywords'):
        literals.append("black_and_white('"+ movie_title +"')")

  #The eval() function is used to evaluate the string representation of 
  #the production_companies attribute as a Python expression, 
  #which converts the string into a list of dictionaries.
  for item in eval(getattr(row, 'production_companies')): 
    production_company = clean_text(item["name"])
    literals.append("production_company('"+ movie_title +"','"+ production_company + "')")

  
  for item in eval(getattr(row, 'production_countries')): 
      production_country = clean_text(item["name"])
      literals.append("production_country('"+ movie_title +"','"+ production_country + "')")

  if(getattr(row, 'title_year') != "UNK"):
        year = int(getattr(row, 'title_year'))
        decade = str(year - year % 10)
        literals.append("decade('"+ movie_title +"','"+ decade + "')")


  



#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db.pl")

# %%
#Consult prolog file containing the rules
prolog.consult("/content/drive/My Drive/predicates.pl")

# %%
q = prolog.query("sameDirector('Unbroken', M)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'In the Land of Blood and Honey', 'By the Sea'}

# %%
q = prolog.query("atLeastFourCommonGenres('World War Z', X)")
s = set()
for sol in q:
   s.add(sol['X'])
q.close()
print(s)
# Out:
# {'The Devils Tomb', 'Alien', 'Outbreak', 'Southland Tales', 'Carriers', 'Pandorum', 'Dragon Wars: D-War', 'Dawn of the Planet of the Apes', 'Class of 1984', 'Capricorn One', 'Echo Dr.', 'Dreamcatcher', 'Elysium', 'The Host', 'Stake Land', 'Daybreakers', 'Spawn', 'Children of Men', 'Aliens', 'Godsend', 'The Darkest Hour', 'Lake Placid', 'Shin Godzilla', 'Anacondas: The Hunt for the Blood Orchid', 'Split Second', 'The Boys from Brazil', 'I Am Legend', 'Firestarter', 'Priest', 'Dylan Dog: Dead of Night', 'Chain Reaction', 'Blade: Trinity', 'The Covenant', 'Aliens vs Predator: Requiem', 'Congo', 'Flatliners', 'They Live', 'Alien Zone', 'Rise of the Planet of the Apes', 'Twilight Zone: The Movie', 'Knowing', 'Vampires', 'eXistenZ', 'Volcano', 'Phantasm II'}

# %%
q = prolog.query("atLeastFiveCommonKeywords('Superman Returns', X)")
s = set()
for sol in q: s.add(sol['X'])
q.close()
print(s)
# Out:
# {'Superman III', 'Superman II', 'Man of Steel', 'Superman', 'Superman IV: The Quest for Peace'}

# %%
q = prolog.query("allThreeCommonActors('Thor', M)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Thor: The Dark World'}

# %%
q = prolog.query("sameLanguage('Pearl Harbor', M)")
for sol in q: print(sol)
q.close()
# Out:
# {'M': '1911'}
# {'M': '8 Women'}
# {'M': 'A Monster in Paris'}
# {'M': 'Aloft'}
# {'M': 'Amour'}
# {'M': 'Amélie'}
# {'M': 'Asterix at the Olympic Games'}
# {'M': 'Barbecue'}
# {'M': 'Betty Fisher and Other Stories'}
# {'M': 'Boomerang'}
# {'M': 'Bottle Shock'}
# {'M': 'Bright Star'}
# {'M': 'Burnt'}
# {'M': 'Camping Sauvage'}
# {'M': 'Captain America: The First Avenger'}
# {'M': 'Caramel'}
# {'M': 'Cargo'}
# {'M': 'Carlos'}
# {'M': 'Cinco de Mayo: La Batalla'}
# {'M': 'Coco Before Chanel'}
# {'M': 'Desire'}
# {'M': 'Dirty Pretty Things'}
# {'M': 'District B13'}
# {'M': 'Dragon Hunters'}
# {'M': 'Elizabeth'}
# {'M': 'Elsa & Fred'}
# {'M': 'Elza'}
# {'M': 'Ernest & Celestine'}
# {'M': 'Evil Words'}
# {'M': 'Evolution'}
# {'M': 'Fly Me to the Moon'}
# {'M': 'Forget Me Not'}
# {'M': 'Grace of Monaco'}
# {'M': 'Guess Who'}
# {'M': 'Hells Angels'}
# {'M': 'History of the World: Part I'}
# {'M': 'Holy Motors'}
# {'M': 'I Am Number Four'}
# {'M': 'Incendies'}
# {'M': 'Intolerable Cruelty'}
# {'M': 'Irreversible'}
# {'M': 'Jumper'}
# {'M': 'Le Havre'}
# {'M': 'Little Nicholas'}
# {'M': 'Little White Lies'}
# {'M': 'March of the Penguins'}
# {'M': 'Master and Commander: The Far Side of the World'}
# {'M': 'Micmacs'}
# {'M': 'Mississippi Mermaid'}
# {'M': 'Moliere'}
# {'M': 'Monty Python and the Holy Grail'}
# {'M': 'Moulin Rouge!'}
# {'M': 'Mozarts Sister'}
# {'M': 'Neal n Nikki'}
# {'M': 'No Escape'}
# {'M': 'Now You See Me'}
# {'M': 'Oceans Twelve'}
# {'M': 'Oceans'}
# {'M': 'One to Another'}
# {'M': 'Oscar and Lucinda'}
# {'M': 'Pierrot le Fou'}
# {'M': 'Rise of the Guardians'}
# {'M': 'Rushmore'}
# {'M': 'See Spot Run'}
# {'M': 'Shrek the Third'}
# {'M': 'Silent Movie'}
# {'M': 'Simply Irresistible'}
# {'M': 'Slumdog Millionaire'}
# {'M': 'Somethings Gotta Give'}
# {'M': 'Spectre'}
# {'M': 'Subway'}
# {'M': 'The Artist'}
# {'M': 'The Awakening'}
# {'M': 'The Blue Room'}
# {'M': 'The Bélier Family'}
# {'M': 'The Case of the Grinning Cat'}
# {'M': 'The Chorus'}
# {'M': 'The Class'}
# {'M': 'The Country Doctor'}
# {'M': 'The Diving Bell and the Butterfly'}
# {'M': 'The Flower of Evil'}
# {'M': 'The Girl on the Train'}
# {'M': 'The Green Mile'}
# {'M': 'The Horseman on the Roof'}
# {'M': 'The Incredibles'}
# {'M': 'The Married Woman'}
# {'M': 'The Names of Love'}
# {'M': 'The Next Best Thing'}
# {'M': 'The Others'}
# {'M': 'The Painted Veil'}
# {'M': 'The Princess and the Frog'}
# {'M': 'The Statement'}
# {'M': 'The Swindle'}
# {'M': 'The Triplets of Belleville'}
# {'M': 'The Visitors II: The Corridors of Time'}
# {'M': 'The Visitors'}
# {'M': 'The Walk'}
# {'M': 'The Widow of Saint-Pierre'}
# {'M': 'The Wolf of Wall Street'}
# {'M': 'They Will Have to Kill Us First'}
# {'M': 'Tinker Tailor Soldier Spy'}
# {'M': 'Up Close & Personal'}
# {'M': 'Wasabi'}
# {'M': 'Welcome to the Sticks'}
# {'M': 'What Just Happened'}
# {'M': 'When the Cats Away'}
# {'M': 'Wild Grass'}

# %%
q = prolog.query("black_and_white(M)")
for sol in q: print(sol)
q.close()
# Out:
# {'M': 'Creative Control'}
# {'M': 'Frances Ha'}
# {'M': 'Frankenweenie'}
# {'M': 'Oceans Eleven'}
# {'M': 'Renaissance'}
# {'M': 'Sin City'}
# {'M': 'The Giver'}
# {'M': 'The Phantom of the Opera'}
# {'M': 'The Waterboy'}

# %%
q = prolog.query("atLeastTwoCommonProductionCompanies('Sin City', M)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Jay and Silent Bob Strike Back', 'Spy Kids', 'From Dusk Till Dawn', 'The Others', 'Grindhouse', 'Once Upon a Time in Mexico'}

# %%
q = prolog.query("commonProductionCountry('Shin Godzilla', M, I)")
s = set()
for sol in q: 
  s.add((sol['M'],sol['I']))
q.close()
print(s)
# Out:
# {('Marie Antoinette', 'Japan'), ('Silent Hill', 'Japan'), ('Ouija', 'Japan'), ('Lara Croft Tomb Raider: The Cradle of Life', 'Japan'), ('The Grudge', 'Japan'), ('Tora! Tora! Tora!', 'Japan'), ('The Worlds Fastest Indian', 'Japan'), ('Godzilla 2000', 'Japan'), ('The Quick and the Dead', 'Japan'), ('Street Fighter: The Legend of Chun-Li', 'Japan'), ('Illuminata', 'Japan'), ('Warcraft', 'Japan'), ('Osama', 'Japan'), ('Street Fighter', 'Japan'), ('Astro Boy', 'Japan'), ('Madadayo', 'Japan'), ('The Relic', 'Japan'), ('Space Pirate Captain Harlock', 'Japan'), ('Wasabi', 'Japan'), ('Brother', 'Japan'), ('Lost in Translation', 'Japan'), ('The Crying Game', 'Japan'), ('Furious 7', 'Japan'), ('Rollerball', 'Japan'), ('Space Battleship Yamato', 'Japan'), ('Bright Lights, Big City', 'Japan'), ('Good Night, and Good Luck.', 'Japan'), ('Seven Samurai', 'Japan'), ('Wonder Boys', 'Japan'), ('Babel', 'Japan'), ('Howls Moving Castle', 'Japan'), ('Blindness', 'Japan'), ('Spirited Away', 'Japan'), ('The Lawnmower Man', 'Japan'), ('Orgazmo', 'Japan'), ('Digimon: The Movie', 'Japan'), ('Ponyo', 'Japan'), ('The Brown Bunny', 'Japan'), ('Day of the Dead', 'Japan'), ('Pokémon: Spell of the Unknown', 'Japan'), ('Princess Mononoke', 'Japan'), ('Primary Colors', 'Japan'), ('One Missed Call', 'Japan'), ('Timecop', 'Japan'), ('The Promise', 'Japan'), ('Joyeux Noël', 'Japan'), ('Control', 'Japan'), ('Cure', 'Japan'), ('R100', 'Japan'), ('Akira', 'Japan'), ('Letters from Iwo Jima', 'Japan'), ('Steamboy', 'Japan'), ('The Last Samurai', 'Japan'), ('Final Fantasy: The Spirits Within', 'Japan'), ('Kama Sutra - A Tale of Love', 'Japan'), ('The Fast and the Furious: Tokyo Drift', 'Japan'), ('3 Ninjas Kick Back', 'Japan')}

# %%
q = prolog.query("sameDecade('A Beautiful Mind', M, D)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Against the Ropes', 'The Night Listener', 'Kings Ransom', 'Pride and Glory', 'Men with Brooms', 'Frailty', 'Sideways', 'Finishing The Game', 'American Outlaws', 'The Count of Monte Cristo', 'Persepolis', 'No Country for Old Men', 'The Adventures of Rocky & Bullwinkle', 'An American Haunting', 'The Ugly Truth', 'Planet of the Apes', 'K-PAX', 'Crazy Heart', 'All the Boys Love Mandy Lane', 'Buffalo Soldiers', '30 Days of Night', 'Glory Road', 'Tropic Thunder', 'The Believer', 'Diary of a Mad Black Woman', 'O Brother, Where Art Thou?', 'Grandmas Boy', 'I Am Legend', 'Traffic', 'American Desi', 'Coach Carter', 'Ayurveda: Art of Being', 'The Grudge', 'Road Trip', 'Ira & Abby', 'Trucker', 'Hot Fuzz', 'Paycheck', 'Meet the Fockers', 'Iron Man', 'Monster-in-Law', 'Serving Sara', 'Valiant', 'The Machinist', 'The Matador', 'The Legend of Suriyothai', 'Goodbye Bafana', 'The One', 'Iris', 'Sympathy for Lady Vengeance', 'Step Up 2: The Streets', 'The Namesake', 'The Upside of Anger', 'The Dark Hours', 'Take the Lead', 'I Want Someone to Eat Cheese With', 'The Young Victoria', 'Resident Evil: Apocalypse', 'Royal Kill', '13 Going on 30', 'The Departed', 'Better Luck Tomorrow', 'Elling', 'Mondays in the Sun', 'Just Married', 'The Curse of the Jade Scorpion', 'The Young Unknowns', 'Catch Me If You Can', 'Black Snake Moan', 'George Washington', 'City of God', 'Finding Nemo', 'Collateral', 'The Fourth Kind', 'Black Hawk Down', 'L.I.E.', 'Miss Congeniality 2: Armed and Fabulous', '3 Strikes', 'The Punisher', 'Babel', 'Crazy Stone', 'From Hell', 'Star Wars: Clone Wars: Volume 1', 'Caramel', 'Romeo Must Die', 'Phone Booth', 'The Spirit', 'Harry Potter and the Order of the Phoenix', 'Taking Woodstock', 'The Work and the Glory II: American Zion', 'Spy Kids 2: The Island of Lost Dreams', 'About Schmidt', 'Dil Jo Bhi Kahey...', 'Nick and Norahs Infinite Playlist', 'Surrogates', 'Free Style', 'Martin Lawrence Live: Runteldat', 'X2', 'A Single Man', 'Quantum of Solace', 'Yes Man', 'Micmacs', 'Extract', 'The Great Debaters', 'The Time Machine', 'What Planet Are You From?', 'Bolt', 'Exit Wounds', 'Letters from Iwo Jima', 'Little Miss Sunshine', 'Pay It Forward', 'Raising Victor Vargas', 'The Lost Skeleton of Cadavra', 'Witless Protection', 'An Everlasting Piece', 'Joe Dirt', 'Bandits', 'Akeelah and the Bee', 'Catwoman', 'Sweet Home Alabama', 'The New World', 'High Tension', 'On The Downlow', 'Flicka', 'Zoom', 'After the Sunset', 'Harts War', 'Vertical Limit', 'Love Actually', 'Rock Star', 'Nims Island', 'Jurassic Park III', 'The Jungle Book 2', 'Wal-Mart: The High Cost of Low Price', 'A Christmas Carol', 'Halloween: Resurrection', 'Samantha: An American Girl Holiday', 'Hearts in Atlantis', 'Scream 3', 'Bend It Like Beckham', 'The Good, The Bad, The Weird', 'Curious George', 'Bringing Down the House', 'Dickie Roberts: Former Child Star', 'Freddy vs. Jason', 'Inside Deep Throat', 'Erin Brockovich', 'Surfer, Dude', 'Wonderland', 'Exiled', 'Howls Moving Castle', 'The Lizzie McGuire Movie', 'Birthday Girl', 'Bon Cop Bad Cop', 'School for Scoundrels', 'Bottle Shock', 'American Gangster', 'What Lies Beneath', 'Sydney White', 'Bubba Ho-tep', 'The Rocket: The Legend of Rocket Richard', 'The Basket', 'Jennifers Body', 'Igby Goes Down', 'Awake', 'The Road to El Dorado', 'Happy Feet', 'Up in the Air', 'The Last House on the Left', 'Shes the Man', 'Fish Tank', 'Happily NEver After', 'In the Cut', 'Before Sunset', 'Red Dragon', 'The Family Stone', 'The Glass House', 'Delgo', 'Once', 'Tae Guk Gi: The Brotherhood of War', 'School of Rock', 'Choke', 'Super Troopers', 'Lara Croft: Tomb Raider', 'Envy', 'Sunshine', 'The Cat in the Hat', 'Blue Crush', 'Imaginary Heroes', 'Special', 'The Baader Meinhof Complex', 'Good Night, and Good Luck.', 'Music and Lyrics', 'One to Another', 'Travellers and Magicians', 'Return to Never Land', 'Capote', 'Red Cliff', 'Say It Isnt So', 'Kung Fu Panda', 'Downfall', 'Alex & Emma', 'The 51st State', 'Extreme Ops', 'An Unfinished Life', 'Dreamgi ...

# %%
q = prolog.query("find_similar_movies_5('Thor',Y)")
s = set()
for sol in q: 
  s.add(sol['Y'])
q.close()
print(s)
# Out:
# {'Cinderella', 'Henry V', 'Jack Ryan: Shadow Recruit', 'Thor: The Dark World'}

# %%
q = prolog.query("find_similar_movies_4('Thor',Y)")
s = set()
for sol in q: 
  s.add(sol['Y'])
q.close()
print(s)
# Out:
# {'Henry V', 'Hamlet', 'Much Ado About Nothing', 'Thor: The Dark World', 'The Magic Flute', 'Cinderella', 'Jack Ryan: Shadow Recruit'}

# %% [markdown]
# Στο αρχείο predicates.pl έχουν συμπεριληφθεί τα κατηγορήματα για όλα queries του ερωτήματος 1β (οριμένα από τα οποία φαίνονται παραπάνω), όπως και οι κανόνες find_similar_movies για το Recommendation System

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
class OrderedSet:
    def __init__(self):
        self._data = []
        self._set = set()

    def add(self, item):
        if item not in self._set:
            self._set.add(item)
            self._data.append(item)

    def __contains__(self, item):
        return item in self._set

    def __iter__(self):
        return iter(self._data)

    def __len__(self):
        return len(self._set)

    def remove(self, item):
        self._set.remove(item)
        self._data.remove(item)

def simple_recommender(movie):
  s = OrderedSet()
  index = []
  for i in [5,4,3,2,1]:
    q = prolog.query("find_similar_movies_" + str(i) + "('" + movie +"',M)")
    for soln in q:
      m = soln['M'] 
      if m not in s:
        s.add(soln['M'])
        index.append(i)
    q.close()
  return list(zip(s,index))

# %%
list(simple_recommender('The Wolf of Wall Street'))
# Out:
# [('Bringing Out the Dead', 5),
#  ('Cape Fear', 5),
#  ('Casino', 5),
#  ('Gangs of New York', 5),
#  ('GoodFellas', 5),
#  ('Hugo', 5),
#  ('Kundun', 5),
#  ('Mean Streets', 5),
#  ('New York, New York', 5),
#  ('Raging Bull', 5),
#  ('Shutter Island', 5),
#  ('Taxi Driver', 5),
#  ('The Age of Innocence', 5),
#  ('The Aviator', 5),
#  ('The Color of Money', 5),
#  ('The Departed', 5),
#  ('The Last Temptation of Christ', 5),
#  ('Shine a Light', 4),
#  ('The Last Waltz', 4),
#  ('Irreversible', 3),
#  ('(500) Days of Summer', 1),
#  ('10 Things I Hate About You', 1),
#  ('102 Dalmatians', 1),
#  ('13 Going on 30', 1),
#  ('16 to Life', 1),
#  ('17 Again', 1),
#  ('1776', 1),
#  ('1941', 1),
#  ('2 Guns', 1),
#  ('20 Dates', 1),
#  ('200 Cigarettes', 1),
#  ('21 & Over', 1),
#  ('21 Jump Street', 1),
#  ('22 Jump Street', 1),
#  ('24 7: Twenty Four Seven', 1),
#  ('27 Dresses', 1),
#  ('28 Days', 1),
#  ('3 Ninjas Kick Back', 1),
#  ('3 Strikes', 1),
#  ('30 Minutes or Less', 1),
#  ('30 Nights of Paranormal Activity With the Devil Inside the Girl With the Dragon Tattoo',
#   1),
#  ('3000 Miles to Graceland', 1),
#  ('40 Days and 40 Nights', 1),
#  ('42nd Street', 1),
#  ('50 First Dates', 1),
#  ('50/50', 1),
#  ('8 Heads in a Duffel Bag', 1),
#  ('8 Women', 1),
#  ('A Beginners Guide to Snuff', 1),
#  ('A Bugs Life', 1),
#  ('A Charlie Brown Christmas', 1),
#  ('A Christmas Story', 1),
#  ('A Cinderella Story', 1),
#  ('A Cock and Bull Story', 1),
#  ('A Dogs Breakfast', 1),
#  ('A Funny Thing Happened on the Way to the Forum', 1),
#  ('A Good Year', 1),
#  ('A Guy Thing', 1),
#  ('A Hard Days Night', 1),
#  ('A Haunted House 2', 1),
#  ('A Haunted House', 1),
#  ('A League of Their Own', 1),
#  ('A Lot Like Love', 1),
#  ('A Low Down Dirty Shame', 1),
#  ('A Madea Christmas', 1),
#  ('A Mighty Wind', 1),
#  ('A Million Ways to Die in the West', 1),
#  ('A Monster in Paris', 1),
#  ('A Night at the Roxbury', 1),
#  ('A Prairie Home Companion', 1),
#  ('A Room for Romeo Brass', 1),
#  ('A Serious Man', 1),
#  ('A Simple Wish', 1),
#  ('A Thin Line Between Love and Hate', 1),
#  ('A Thousand Words', 1),
#  ('A True Story', 1),
#  ('A Very Harold & Kumar Christmas', 1),
#  ('A Woman, a Gun and a Noodle Shop', 1),
#  ('Aberdeen', 1),
#  ('About Last Night', 1),
#  ('About Schmidt', 1),
#  ('About Time', 1),
#  ('About a Boy', 1),
#  ('Accidental Love', 1),
#  ('Ace Ventura: Pet Detective', 1),
#  ('Ace Ventura: When Nature Calls', 1),
#  ('Action Jackson', 1),
#  ('Adaptation.', 1),
#  ('Admission', 1),
#  ('Adventureland', 1),
#  ('After the Sunset', 1),
#  ('Agent Cody Banks 2: Destination London', 1),
#  ('Air Bud', 1),
#  ('Airborne', 1),
#  ('Airplane!', 1),
#  ('Aladdin', 1),
#  ('Alex & Emma', 1),
#  ('Alexander and the Terrible, Horrible, No Good, Very Bad Day', 1),
#  ('Alfie', 1),
#  ('Aliens in the Attic', 1),
#  ('All About Steve', 1),
#  ('All About the Benjamins', 1),
#  ('All Hat', 1),
#  ('All Is Bright', 1),
#  ('All The Queens Men', 1),
#  ('All or Nothing', 1),
#  ('Aloha', 1),
#  ('Along Came Polly', 1),
#  ('Along the Roadside', 1),
#  ('Alpha and Omega: The Legend of the Saw Tooth Cave', 1),
#  ('Alvin and the Chipmunks', 1),
#  ('Alvin and the Chipmunks: Chipwrecked', 1),
#  ('Alvin and the Chipmunks: The Road Chip', 1),
#  ('Alvin and the Chipmunks: The Squeakquel', 1),
#  ('American Desi', 1),
#  ('American Dreamz', 1),
#  ('American Graffiti', 1),
#  ('American Hero', 1),
#  ('American Pie 2', 1),
#  ('American Pie', 1),
#  ('American Reunion', 1),
#  ('American Splendor', 1),
#  ('American Wedding', 1),
#  ('Americas Sweethearts', 1),
#  ('Among Giants', 1),
#  ('Amélie', 1),
#  ('An Alan Smithee Film: Burn, Hollywood, Burn', 1),
#  ('An American Carol', 1),
#  ('An Everlasting Piece', 1),
#  ('An Ideal Husband', 1),
#  ('Analyze That', 1),
#  ('Analyze This', 1),
#  ('Anchorman 2: The Legend Continues', 1),
#  ('Anchorman: The Legend of Ron Burgundy', 1),
#  ('And So It Goes', 1),
#  ('And Then Came Love', 1),
#  ('Andersons Cross', 1),
#  ('Animal House', 1),
#  ('Animals United', 1),
#  ('Annie Get Your Gun', 1),
#  ('Annie Hall', 1),
#  ('Annie', 1),
#  ('Anomalisa', 1),
#  ('Another Happy Day', 1),
#  ('Another Year', 1),
#  ('Antz', 1),
#  ('Anything Else', 1),
#  ('Anywhere But Here', 1),
#  ('Aqua Teen Hunger Force Colon Movie Film for Theaters', 1),
#  ('Aquamarine', 1),
#  ('Arachnophobia', 1),
#  ('Are We There Yet?', 1),
#  ('Army of Darkness', 1),
#  ('Around the World in 80 Days', 1),
#  ('Arthur Christmas', 1),
#  ('As Good as It Gets', 1),
#  ('As It Is in Heaven', 1),
#  ('Asterix at the Olympic Games', 1),
#  ('Attack the Block', 1),
#  ('August: Osage County', 1),
#  ('Austin Powers in Goldmember', 1),
#  ('Austin Powers: International Man of Mystery', 1),
#  ('Austin Powers: The Spy Who Shagged Me', 1),
#  ('Away We Go', 1),
#  ('Babe', 1),
#  ('Babe: Pig in the City', 1),
#  ('Baby Geniuses', 1),
#  ('Baby Mama', 1),
#  ('Babys Day Out', 1),
#  ('Bachelorette', 1),
#  ('Back to the Future Part II', 1),
#  ('Back to the Future Part III', 1),
#  ('Back to the Future', 1),
#  ('Bad Boys II', 1),
#  ('Bad Boys', 1),
#  ('Bad Company', 1),
#  ('Bad Grandpa', 1),
#  ('Bad Moms', 1),
#  ('Bad Santa', 1),
#  ('Bad Teacher', 1),
#  ('Bad Words', 1),
#  ('Baggage Claim', 1),
#  ('Baghead', 1),
#  ('Bamboozled', 1),
#  ('Bananas', 1),
#  ('Bandidas', 1),
#  ('Bandits', 1),
#  ('Bandslam', 1),
#  ('Barbecue', 1),
#  ('Barbershop 2:  Back in Business', 1),
#  ('Barbershop', 1),
#  ('Barneys Version', 1),
#  ('Barnyard', 1),
#  ('Barry Munday', 1),
#  ('Bathing Beauty', 1),
#  ('Batman', 1),
#  ('Be Cool', 1),
#  ('Be Kind Rewind', 1),
#  ('Beauty Shop', 1),
#  ('Beavis and Butt-Head Do America', 1),
#  ('Because I Said So', 1),
#  ('Because of Winn-Dixie', 1),
#  ('Bedazzled', 1),
#  ('Bedtime Stories', 1),
#  ('Bee Movie', 1),
#  ('Beer League', 1),
#  ('Beerfest', 1),
#  ('Beetlejuice', 1),
#  ('Begin Again', 1),
#  ('Beginners', 1),
#  ('Being John Malkovich', 1),
#  ('Being Julia', 1),
#  ('Bend It Like Beckham', 1),
#  ('Bernie', 1),
#  ('Best in Show', 1),
#  ('Beverly Hills Chihuahua', 1),
#  ('Beverly Hills Cop II', 1),
#  ('Beverly Hills Cop III', 1),
#  ('Beverly Hills Cop', 1),
#  ('Beyond the Valley of the Dolls', 1),
#  ('Bicentennial Man', 1),
#  ('Big Daddy', 1),
#  ('Big Fat Liar', 1),
#  ('Big Hero 6', 1),
#  ('Big Mommas House 2', 1),
#  ('Big Mommas House', 1),
#  ('Big Mommas: Like Father, Like Son', 1),
#  ('Big Trouble in Little China', 1),
#  ('Big Trouble', 1),
#  ('Big', 1),
#  ('Bill & Teds Bogus Journey', 1),
#  ('Bill & Teds Excellent Adventure', 1),
#  ('Billy Elliot', 1),
#  ('Birdman', 1),
#  ('Birthday Girl', 1),
#  ('Black Knight', 1),
#  ('Blades of Glory', 1),
#  ('Blast from the Past', 1),
#  ('Blazing Saddles', 1),
#  ('Blended', 1),
#  ('Blonde Ambition', 1),
#  ('Blue Jasmine', 1),
#  ('Blue Like Jazz', 1),
#  ('Blue Streak', 1),
#  ('Boat Trip', 1),
#  ('Bogus', 1),
#  ('Bolt', 1),
#  ('Bon Cop Bad Cop', 1),
#  ('Bon voyage', 1),
#  ('Boomerang', 1),
#  ('Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   1),
#  ('Bottle Rocket', 1),
#  ('Bottle Shock', 1),
#  ('Bowfinger', 1),
#  ('Boynton Beach Club', 1),
#  ('Boys and Girls', 1),
#  ('Bran Nue Dae', 1),
#  ('Brave', 1),
#  ('Brazil', 1),
#  ('Breakfast of Champions', 1),
#  ('Breakin All the Rules', 1),
#  ('Breaking Upwards', 1),
#  ('Bride & Prejudice', 1),
#  ('Bride Wars', 1),
#  ('Bride of Chucky', 1),
#  ('Bridesmaids', 1),
#  ('Bridget Jones: The Edge of Reason', 1),
#  ('Bridget Joness Diary', 1),
#  ('Bring It On', 1),
#  ('Bringing Down the House', 1),
#  ('Brown Sugar', 1),
#  ('Bruce Almighty', 1),
#  ('Brüno', 1),
#  ('Bubba Ho-tep', 1),
#  ('Bubble Boy', 1),
#  ('Bucky Larson: Born to Be a Star', 1),
#  ('Buffalo 66', 1),
#  ('Buffalo Soldiers', 1),
#  ('Bulletproof Monk', 1),
#  ('Bullets Over Broadway', 1),
#  ('Bulworth', 1),
#  ('Burn After Reading', 1),
#  ('But Im a Cheerleader', 1),
#  ('CJ7', 1),
#  ('Ca$h', 1),
#  ('Caddyshack', 1),
#  ('Cant Hardly Wait', 1),
#  ('Cant Stop the Music', 1),
#  ('Caramel', 1),
#  ('Carnage', 1),
#  ('Cars 2', 1),
#  ('Cars', 1),
#  ('Casa De Mi Padre', 1),
#  ('Casino Jack', 1),
#  ('Casper', 1),
#  ('Catch-22', 1),
#  ('Cats & Dogs 2 : The Revenge of Kitty Galore', 1),
#  ('Cats & Dogs', 1),
#  ('Cats Dont Dance', 1),
#  ('Cecil B. Demented', 1),
#  ('Cedar Rapids', 1),
#  ('Celebrity', 1),
#  ('Celeste & Jesse Forever', 1),
#  ('Central Intelligence', 1),
#  ('Certifiably Jonathan', 1),
#  ('Chairman of the Board', 1),
#  ('Charlie Bartlett', 1),
#  ('Charlie Wilsons War', 1),
#  ('Charlie and the Chocolate Factory', 1),
#  ('Charlies Angels', 1),
#  ('Charlies Angels: Full Throttle', 1),
#  ('Charlottes Web', 1),
#  ('Chasing Amy', 1),
#  ('Chasing Liberty', 1),
#  ('Chasing Papi', 1),
#  ('Cheap Thrills', 1),
#  ('Cheaper by the Dozen 2', 1),
#  ('Cheaper by the Dozen', 1),
#  ('Cheri', 1),
#  ('Chicago', 1),
#  ('Chicken Little', 1),
#  ('Chicken Run', 1),
#  ('Chicken Tikka Masala', 1),
#  ('Children of Heaven', 1),
#  ('Chill Factor', 1),
#  ('Chocolat', 1),
#  ('Choke', 1),
#  ('Christmas Eve', 1),
#  ('Christmas Mail', 1),
#  ('Christmas with the Kranks', 1),
#  ('Chuck & Buck', 1),
#  ('City Island', 1),
#  ('Clay Pigeons', 1),
#  ('Clerks II', 1),
#  ('Clerks', 1),
#  ('Click', 1),
#  ('Clockwatchers', 1),
#  ('Closer to the Moon', 1),
#  ('Cloudy with a Chance of Meatballs 2', 1),
#  ('Cloudy with a Chance of Meatballs', 1),
#  ('Club Dread', 1),
#  ('Clueless', 1),
#  ('Code Name: The Cleaner', 1),
#  ('Coffee Town', 1),
#  ('College', 1),
#  ('Compadres', 1),
#  ('Confessions of a Dangerous Mind', 1),
#  ('Confessions of a Teenage Drama Queen', 1),
#  ('Confidence', 1),
#  ('Connie and Carla', 1),
#  ('Cool Runnings', 1),
#  ('Cop Out', 1),
#  ('Corky Romano', 1),
#  ('Couples Retreat', 1),
#  ('Coyote Ugly', 1),
#  ('Crazy Stone', 1),
#  ('Crazy in Alabama', 1),
#  ('Crazy, Stupid, Love.', 1),
#  ('Creepshow', 1),
#  ('Critical Care', 1),
#  ('Crocodile Dundee II', 1),
#  ('Crocodile Dundee in Los Angeles', 1),
#  ('Crocodile Dundee', 1),
#  ('Crooklyn', 1),
#  ('Crossroads', 1),
#  ('Crying with Laughter', 1),
#  ('Curious George', 1),
#  ('Cursed', 1),
#  ('Cyrus', 1),
#  ('Da Sweet Blood of Jesus', 1),
#  ('Daddy Day Camp', 1),
#  ('Daddy Day Care', 1),
#  ('Daddys Home', 1),
#  ('Damsels in Distress', 1),
#  ('Dance Flick', 1),
#  ('Dancer, Texas Pop. 81', 1),
#  ('Danny Collins', 1),
#  ('Dark Shadows', 1),
#  ('Darling Lili', 1),
#  ('Date Movie', 1),
#  ('Date Night', 1),
#  ('Dave Chappelles Block Party', 1),
#  ('Dazed and Confused', 1),
#  ('Dead Like Me: Life After Death', 1),
#  ('Dead Man on Campus', 1),
#  ('Dead Snow', 1),
#  ('Deadpool', 1),
#  ('Dear Wendy', 1),
#  ('Death Becomes Her', 1),
#  ('Death Race 2000', 1),
#  ('Death at a Funeral', 1),
#  ('Death to Smoochy', 1),
#  ('Deck the Halls', 1),
#  ('Deconstructing Harry', 1),
#  ('Def Jams How to Be a Player', 1),
#  ('Defendor', 1),
#  ('Definitely, Maybe', 1),
#  ('Delgo', 1),
#  ('Delivery Man', 1),
#  ('Desert Blue', 1),
#  ('Despicable Me 2', 1),
#  ('Detention of the Dead', 1),
#  ('Detention', 1),
#  ('Detroit Rock City', 1),
#  ('Deuce Bigalow: European Gigolo', 1),
#  ('Deuce Bigalow: Male Gigolo', 1),
#  ('Diary of a Mad Black Woman', 1),
#  ('Diary of a Wimpy Kid', 1),
#  ('Diary of a Wimpy Kid: Dog Days', 1),
#  ('Diary of a Wimpy Kid: Rodrick Rules', 1),
#  ('Dick Tracy', 1),
#  ('Dick', 1),
#  ('Dickie Roberts: Former Child Star', 1),
#  ('Did You Hear About the Morgans?', 1),
#  ('Diner', 1),
#  ('Dinner for Schmucks', 1),
#  ('Dirty Grandpa', 1),
#  ('Dirty Work', 1),
#  ('Disaster Movie', 1),
#  ('Divine Secrets of the Ya-Ya Sisterhood', 1),
#  ('Doctor Dolittle', 1),
#  ('DodgeBall: A True Underdog Story', 1),
#  ('Dogma', 1),
#  ('Dom Hemingway', 1),
#  ('Don Jon', 1),
#  ('Don Juan DeMarco', 1),
#  ('Donovans Reef', 1),
#  ('Dope', 1),
#  ('Double Take', 1),
#  ('Dougs 1st Movie', 1),
#  ('Down & Out With The Dolls', 1),
#  ('Down Terrace', 1),
#  ('Down to Earth', 1),
#  ('Down to You', 1),
#  ('Dr. Dolittle 2', 1),
#  ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 1),
#  ('Dream with the Fishes', 1),
#  ('Drillbit Taylor', 1),
#  ('Drive Hard', 1),
#  ('Drive Me Crazy', 1),
#  ('Driving Lessons', 1),
#  ('Driving Miss Daisy', 1),
#  ('Drop Dead Gorgeous', 1),
#  ('Drowning Mona', 1),
#  ('Drumline', 1),
#  ('Dry Spell', 1),
#  ('Dude, Where’s My Car?', 1),
#  ('Dudley Do-Right', 1),
#  ('Due Date', 1),
#  ('Duets', 1),
#  ('Dumb and Dumber To', 1),
#  ('Dumb and Dumber', 1),
#  ('Dumb and Dumberer: When Harry Met Lloyd', 1),
#  ('Duplex', 1),
#  ('Duplicity', 1),
#  ('Dylan Dog: Dead of Night', 1),
#  ('DysFunktional Family', 1),
#  ('Dysfunctional Friends', 1),
#  ('East Is East', 1),
#  ('Easy A', 1),
#  ('Easy Virtue', 1),
#  ('Ed Wood', 1),
#  ('Ed and His Dead Mother', 1),
#  ('Eddie the Eagle', 1),
#  ('Eddie: The Sleepwalking Cannibal', 1),
#  ('Edtv', 1),
#  ('Eight Legged Freaks', 1),
#  ('Election', 1),
#  ('Elf', 1),
#  ('Elizabethtown', 1),
#  ('Ella Enchanted', 1),
#  ('Elling', 1),
#  ('Elsa & Fred', 1),
#  ('Emma', 1),
#  ('Employee of the Month', 1),
#  ('Enchanted', 1),
#  ('Enough Said', 1),
#  ('Envy', 1),
#  ('Epic Movie', 1),
#  ('Ernest & Celestine', 1),
#  ('Escape from Planet Earth', 1),
#  ('Eulogy', 1),
#  ('EuroTrip', 1),
#  ('Evan Almighty', 1),
#  ('Ever After: A Cinderella Story', 1),
#  ('Everyone Says I Love You', 1),
#  ('Everything Must Go', 1),
#  ('Everything You Always Wanted to Know About Sex *But Were Afraid to Ask', 1),
#  ('Evil Dead II', 1),
#  ('Extract', 1),
#  ('Extreme Movie', 1),
#  ('Failure to Launch', 1),
#  ('Faithful', 1),
#  ('Fame', 1),
#  ('Family Plot', 1),
#  ('Fantastic Mr. Fox', 1),
#  ('Farce of the Penguins', 1),
#  ('Fast Times at Ridgemont High', 1),
#  ('Fat Albert', 1),
#  ('Fear and Loathing in Las Vegas', 1),
#  ('Feast', 1),
#  ('Fetching Cody', 1),
#  ('Fever Pitch', 1),
#  ('Fido', 1),
#  ('Fifty Shades of Black', 1),
#  ('Find Me Guilty', 1),
#  ('Finishing The Game', 1),
#  ('Flawless', 1),
#  ('Fled', 1),
#  ('Flirting with Disaster', 1),
#  ('Florence Foster Jenkins', 1),
#  ('Flubber', 1),
#  ('Flushed Away', 1),
#  ('Fly Me to the Moon', 1),
#  ('Focus', 1),
#  ('Foodfight!', 1),
#  ('Foolish', 1),
#  ('Fools Gold', 1),
#  ('For Your Consideration', 1),
#  ('For a Good Time, Call...', 1),
#  ('Forgetting Sarah Marshall', 1),
#  ('Forrest Gump', 1),
#  ('Four Christmases', 1),
#  ('Four Lions', 1),
#  ('Four Rooms', 1),
#  ('Four Single Fathers', 1),
#  ('Four Weddings and a Funeral', 1),
#  ('Frances Ha', 1),
#  ('Frankenweenie', 1),
#  ('Frat Party', 1),
#  ('Freaky Deaky', 1),
#  ('Freaky Friday', 1),
#  ('Freddy Got Fingered', 1),
#  ('Freddys Dead: The Final Nightmare', 1),
#  ('Free Birds', 1),
#  ('Freeway', 1),
#  ('Friday After Next', 1),
#  ('Friday', 1),
#  ('Friends with Benefits', 1),
#  ('Friends with Money', 1),
#  ('Fright Night', 1),
#  ('From Justin to Kelly', 1),
#  ('From a Whisper to a Scream', 1),
#  ('Fugly', 1),
#  ('Full Frontal', 1),
#  ('Fun Size', 1),
#  ('Fun with Dick and Jane', 1),
#  ('Funny Ha Ha', 1),
#  ('Funny People', 1),
#  ('Furry Vengeance', 1),
#  ('G-Force', 1),
#  ('Galaxina', 1),
#  ('Galaxy Quest', 1),
#  ('Garden State', 1),
#  ('Garfield', 1),
#  ('Garfield: A Tail of Two Kitties', 1),
#  ('Gentlemen Broncos', 1),
#  ('George of the Jungle', 1),
#  ('Georgia Rule', 1),
#  ('Get Hard', 1),
#  ('Get Him to the Greek', 1),
#  ('Get Low', 1),
#  ('Get Over It', 1),
#  ('Get Shorty', 1),
#  ('Get Smart', 1),
#  ('Ghost Town', 1),
#  ('Ghost World', 1),
#  ('Ghostbusters', 1),
#  ('Girl 6', 1),
#  ('Girls Gone Dead', 1),
#  ('Go', 1),
#  ('Going the Distance', 1),
#  ('Good Boy!', 1),
#  ('Good Deeds', 1),
#  ('Good Dick', 1),
#  ('Good Intentions', 1),
#  ('Good Luck Chuck', 1),
#  ('Good Morning, Vietnam', 1),
#  ('Good bye, Lenin!', 1),
#  ('Goosebumps', 1),
#  ('Grabbers', 1),
#  ('Grand Theft Parsons', 1),
#  ('Grandmas Boy', 1),
#  ('Gremlins 2: The New Batch', 1),
#  ('Gremlins', 1),
#  ('Griff the Invisible', 1),
#  ('Grosse Pointe Blank', 1),
#  ('Groundhog Day', 1),
#  ('Growing Up Smith', 1),
#  ('Grown Ups 2', 1),
#  ('Grown Ups', 1),
#  ('Grudge Match', 1),
#  ('Guess Who', 1),
#  ('Gullivers Travels', 1),
#  ('Gun Shy', 1),
#  ('Gunless', 1),
#  ('Hail, Caesar!', 1),
#  ('Hairspray', 1),
#  ('Half Baked', 1),
#  ('Hall Pass', 1),
#  ('Hamlet 2', 1),
#  ('Hanging Up', 1),
#  ('Hannah Montana: The Movie', 1),
#  ('Hansel and Gretel Get Baked', 1),
#  ('Happily NEver After', 1),
#  ('Happiness', 1),
#  ('Happy Christmas', 1),
#  ('Happy Feet Two', 1),
#  ('Happy Feet', 1),
#  ('Happy Gilmore', 1),
#  ('Happy, Texas', 1),
#  ('Hardball', 1),
#  ('Harold & Kumar Escape from Guantanamo Bay', 1),
#  ('Harold & Kumar Go to White Castle', 1),
#  ('Harriet the Spy', 1),
#  ('Hatchet', 1),
#  ('Hav Plenty', 1),
#  ('Head Over Heels', 1),
#  ('Head of State', 1),
#  ('Heartbeeps', 1),
#  ('Heartbreakers', 1),
#  ('Hedwig and the Angry Inch', 1),
#  ('Held Up', 1),
#  ('Herbie Fully Loaded', 1),
#  ('Here Comes the Boom', 1),
#  ('Hes Just Not That Into You', 1),
#  ('High Anxiety', 1),
#  ('High Fidelity', 1),
#  ('High Heels and Low Lifes', 1),
#  ('High Road', 1),
#  ('High School Musical 2', 1),
#  ('High School Musical 3: Senior Year', 1),
#  ('High School Musical', 1),
#  ('History of the World: Part I', 1),
#  ('Hit & Run', 1),
#  ('Hitch', 1),
#  ('Hits', 1),
#  ('Hobo with a Shotgun', 1),
#  ('Hocus Pocus', 1),
#  ('Holes', 1),
#  ('Hollywood Ending', 1),
#  ('Hollywood Homicide', 1),
#  ('Hollywood Shuffle', 1),
#  ('Holy Man', 1),
#  ('Home Alone 2: Lost in New York', 1),
#  ('Home Alone', 1),
#  ('Home Fries', 1),
#  ('Home for the Holidays', 1),
#  ('Home', 1),
#  ('Hoodwinked Too! Hood VS. Evil', 1),
#  ('Hoodwinked!', 1),
#  ('Hook', 1),
#  ('Hop', 1),
#  ('Hope Springs', 1),
#  ('Horrible Bosses 2', 1),
#  ('Horrible Bosses', 1),
#  ('Hot Fuzz', 1),
#  ('Hot Pursuit', 1),
#  ('Hot Rod', 1),
#  ('Hot Tub Time Machine 2', 1),
#  ('Hot Tub Time Machine', 1),
#  ('Hotel Transylvania 2', 1),
#  ('Hotel Transylvania', 1),
#  ('Hotel for Dogs', 1),
#  ('House Party 2', 1),
#  ('House of D', 1),
#  ('Housebound', 1),
#  ('Housefull', 1),
#  ('How Do You Know', 1),
#  ('How High', 1),
#  ('How Stella Got Her Groove Back', 1),
#  ('How the Grinch Stole Christmas', 1),
#  ('How to Be Single', 1),
#  ('How to Deal', 1),
#  ('How to Fall in Love', 1),
#  ('How to Lose Friends & Alienate People', 1),
#  ('How to Lose a Guy in 10 Days', 1),
#  ('How to Train Your Dragon 2', 1),
#  ('Howard the Duck', 1),
#  ('Hudson Hawk', 1),
#  ('Human Traffic', 1),
#  ('I Can Do Bad All By Myself', 1),
#  ('I Dont Know How She Does It', 1),
#  ('I Got the Hook Up', 1),
#  ('I Heart Huckabees', 1),
#  ('I Hope They Serve Beer in Hell', 1),
#  ('I Love You Phillip Morris', 1),
#  ('I Love You, Beth Cooper', 1),
#  ('I Love You, Dont Touch Me!', 1),
#  ('I Love You, Man', 1),
#  ('I Married a Strange Person!', 1),
#  ('I Served the King of England', 1),
#  ('I Spy', 1),
#  ('I Think I Love My Wife', 1),
#  ('I Want Someone to Eat Cheese With', 1),
#  ('Ice Age', 1),
#  ('Ice Age: Continental Drift', 1),
#  ('Ice Age: Dawn of the Dinosaurs', 1),
#  ('Ice Age: The Meltdown', 1),
#  ('Ice Princess', 1),
#  ('Identity Thief', 1),
#  ('Idiocracy', 1),
#  ('Idle Hands', 1),
#  ('Igby Goes Down', 1),
#  ('Imaginary Heroes', 1),
#  ('Imagine Me & You', 1),
#  ('Imagine That', 1),
#  ('In & Out', 1),
#  ('In Bruges', 1),
#  ('In Good Company', 1),
#  ('In the Company of Men', 1),
#  ('In the Land of Women', 1),
#  ('Incident at Loch Ness', 1),
#  ('Inherent Vice', 1),
#  ('Inside Out', 1),
#  ('Inspector Gadget', 1),
#  ('Instructions Not Included', 1),
#  ('Into the Woods', 1),
#  ('Intolerable Cruelty', 1),
#  ('Ira & Abby', 1),
#  ('Ishtar', 1),
#  ('Isnt She Great', 1),
#  ('It Happened One Night', 1),
#  ('Its All Gone Pete Tong', 1),
#  ('Its Complicated', 1),
#  ('Its Kind of a Funny Story', 1),
#  ('Its a Mad, Mad, Mad, Mad World', 1),
#  ('Its a Wonderful Afterlife', 1),
#  ('Jack Brooks: Monster Slayer', 1),
#  ('Jack and Jill', 1),
#  ('Jackass 3D', 1),
#  ('Jackass Number Two', 1),
#  ('Jackass: The Movie', 1),
#  ('Jackie Brown', 1),
#  ('Jakob the Liar', 1),
#  ('Janky Promoters', 1),
#  ('Jawbreaker', 1),
#  ('Jay and Silent Bob Strike Back', 1),
#  ('Jeff, Who Lives at Home', 1),
#  ('Jekyll and Hyde ... Together Again', 1),
#  ('Jennifers Body', 1),
#  ('Jerry Maguire', 1),
#  ('Jersey Girl', 1),
#  ('Jesus Son', 1),
#  ('Jimmy Neutron: Boy Genius', 1),
#  ('Jingle All the Way', 1),
#  ('Joe Dirt', 1),
#  ('Joe Somebody', 1),
#  ('Johnny English Reborn', 1),
#  ('Johnny English', 1),
#  ('Johnny Suede', 1),
#  ('Johnson Family Vacation', 1),
#  ('Jonah: A VeggieTales Movie', 1),
#  ('Josie and the Pussycats', 1),
#  ('Journey to Saturn', 1),
#  ('Journey to the Center of the Earth', 1),
#  ('Joy', 1),
#  ('Joyful Noise', 1),
#  ('Juliet and Alfa Romeo', 1),
#  ('Jumping the Broom', 1),
#  ('Juno', 1),
#  ('Just Go with It', 1),
#  ('Just Like Heaven', 1),
#  ('Just Looking', 1),
#  ('Just Married', 1),
#  ('Just My Luck', 1),
#  ('Just Visiting', 1),
#  ('Just Wright', 1),
#  ('Juwanna Mann', 1),
#  ('Kangaroo Jack', 1),
#  ('Karachi se Lahore', 1),
#  ('Kate & Leopold', 1),
#  ('Keanu', 1),
#  ('Keeping Up with the Steins', 1),
#  ('Keeping the Faith', 1),
#  ('Kevin Hart: Laugh at My Pain', 1),
#  ('Kevin Hart: Let Me Explain', 1),
#  ('Khiladi 786', 1),
#  ('Kicking & Screaming', 1),
#  ('Killers', 1),
#  ('Kindergarten Cop', 1),
#  ('Kingpin', 1),
#  ('Kings Ransom', 1),
#  ('Kiss Kiss Bang Bang', 1),
#  ('Kiss the Bride', 1),
#  ('Kissing Jessica Stein', 1),
#  ('Kit Kittredge: An American Girl', 1),
#  ('Knight and Day', 1),
#  ('Knocked Up', 1),
#  ('Krampus', 1),
#  ('Kung Fu Hustle', 1),
#  ('Kung Fu Panda 3', 1),
#  ('Kung Fu Panda', 1),
#  ('Kung Pow: Enter the Fist', 1),
#  ('L!fe Happens', 1),
#  ('LOL', 1),
#  ('Lage Raho Munna Bhai', 1),
#  ('Lake Placid', 1),
#  ('Land of the Lost', 1),
#  ('Larry Crowne', 1),
#  ('Larry the Cable Guy: Health Inspector', 1),
#  ('Lars and the Real Girl', 1),
#  ('Last Action Hero', 1),
#  ('Last Holiday', 1),
#  ('Last I Heard', 1),
#  ('Last Orders', 1),
#  ('Last Vegas', 1),
#  ('Latter Days', 1),
#  ('Laws of Attraction', 1),
#  ('Le Havre', 1),
#  ('Leap Year', 1),
#  ('Leatherheads', 1),
#  ('Legal Eagles', 1),
#  ('Legally Blonde 2: Red, White & Blonde', 1),
#  ('Legally Blonde', 1),
#  ('Legend of a Rabbit', 1),
#  ('Lesbian Vampire Killers', 1),
#  ('Lethal Weapon 3', 1),
#  ('Lethal Weapon 4', 1),
#  ('Lets Be Cops', 1),
#  ('Lets Go to Prison', 1),
#  ('Lets Kill Wards Wife', 1),
#  ('Letters to Juliet', 1),
#  ('Liar Liar', 1),
#  ('License to Wed', 1),
#  ('Life During Wartime', 1),
#  ('Life or Something Like It', 1),
#  ('Like Mike', 1),
#  ('Little Big Top', 1),
#  ('Little Black Book', 1),
#  ('Little Boy', 1),
#  ('Little Fockers', 1),
#  ('Little Man', 1),
#  ('Little Miss Sunshine', 1),
#  ('Little Nicholas', 1),
#  ('Little Nicky', 1),
#  ('Little Shop of Horrors', 1),
#  ('Little Voice', 1),
#  ('Little White Lies', 1),
#  ('Living Out Loud', 1),
#  ('Lock, Stock and Two Smoking Barrels', 1),
#  ('Lonesome Jim', 1),
#  ('Looney Tunes: Back in Action', 1),
#  ('Loose Cannons', 1),
#  ('Loser', 1),
#  ('Losin It', 1),
#  ('Lottery Ticket', 1),
#  ('Love & Basketball', 1),
#  ('Love & Other Drugs', 1),
#  ('Love Actually', 1),
#  ('Love Jones', 1),
#  ('Love Stinks', 1),
#  ('Love and Other Catastrophes', 1),
#  ('Love in the Time of Monsters', 1),
#  ('Love the Coopers', 1),
#  ('Lovely & Amazing', 1),
#  ('Lucky Break', 1),
#  ('Lucky Numbers', 1),
#  ('MacGruber', 1),
#  ('Machete', 1),
#  ('Mad Money', 1),
#  ('Made in Dagenham', 1),
#  ('Made of Honor', 1),
#  ('Made', 1),
#  ('Madea Goes to Jail', 1),
#  ('Madeas Family Reunion', 1),
#  ('Madeas Witness Protection', 1),
#  ('Magic Mike XXL', 1),
#  ('Magic Mike', 1),
#  ('Maid in Manhattan', 1),
#  ('Major League', 1),
#  ('Malibus Most Wanted', 1),
#  ('Mallrats', 1),
#  ('Mambo Italiano', 1),
#  ('Mamma Mia!', 1),
#  ('Man of the House', 1),
#  ('Man of the Year', 1),
#  ('Man on the Moon', 1),
#  ('Marci X', 1),
#  ('Marley & Me', 1),
#  ('Marmaduke', 1),
#  ('Mars Attacks!', 1),
#  ('Martin Lawrence Live: Runteldat', 1),
#  ('Mary Poppins', 1),
#  ('Max Keebles Big Move', 1),
#  ('Me You and Five Bucks', 1),
#  ('Me and Orson Welles', 1),
#  ('Me and You and Everyone We Know', 1),
#  ('Me, Myself & Irene', 1),
#  ('Mean Girls', 1),
#  ('Mean Machine', 1),
#  ('Meet Dave', 1),
#  ('Meet the Deedles', 1),
#  ('Meet the Fockers', 1),
#  ('Meet the Parents', 1),
#  ('Meet the Spartans', 1),
#  ('Megamind', 1),
#  ('Memoirs of an Invisible Man', 1),
#  ('Men in Black 3', 1),
#  ('Men in Black II', 1),
#  ('Men in Black', 1),
#  ('Men with Brooms', 1),
#  ('Metropolitan', 1),
#  ('Mickey Blue Eyes', 1),
#  ('Micmacs', 1),
#  ('Midnight Run', 1),
#  ('Midnight in Paris', 1),
#  ('Minions', 1),
#  ('Mirror Mirror', 1),
#  ('Miss Congeniality 2: Armed and Fabulous', 1),
#  ('Miss Congeniality', 1),
#  ('Miss March', 1),
#  ('Modern Problems', 1),
#  ('Modern Times', 1),
#  ('Moliere', 1),
#  ('Molly', 1),
#  ('Moms Night Out', 1),
#  ('Money Talks', 1),
#  ('Money Train', 1),
#  ('Monkeybone', 1),
#  ('Monsoon Wedding', 1),
#  ('Monster House', 1),
#  ('Monster-in-Law', 1),
#  ('Monsters, Inc.', 1),
#  ('Monte Carlo', 1),
#  ('Monty Python and the Holy Grail', 1),
#  ('Moonrise Kingdom', 1),
#  ('Morning Glory', 1),
#  ('Mortdecai', 1),
#  ('Motherhood', 1),
#  ('Movie 43', 1),
#  ('Mr. & Mrs. Smith', 1),
#  ('Mr. 3000', 1),
#  ('Mr. Beans Holiday', 1),
#  ('Mr. Deeds', 1),
#  ('Mr. Nice Guy', 1),
#  ('Mr. Poppers Penguins', 1),
#  ('Mr. Smith Goes to Washington', 1),
#  ('Mrs Henderson Presents', 1),
#  ('Mrs. Doubtfire', 1),
#  ('Mrs. Winterbourne', 1),
#  ('Much Ado About Nothing', 1),
#  ('Multiplicity', 1),
#  ('Mumford', 1),
#  ('Muppets Most Wanted', 1),
#  ('Muppets from Space', 1),
#  ('Music and Lyrics', 1),
#  ('Must Love Dogs', 1),
#  ('Mutual Appreciation', 1),
#  ('My Babys Daddy', 1),
#  ('My Beautiful Laundrette', 1),
#  ('My Best Friends Girl', 1),
#  ('My Best Friends Wedding', 1),
#  ('My Big Fat Greek Wedding 2', 1),
#  ('My Big Fat Greek Wedding', 1),
#  ('My Big Fat Independent Movie', 1),
#  ('My Bosss Daughter', 1),
#  ('My Cousin Vinny', 1),
#  ('My Dog Skip', 1),
#  ('My Dog Tulip', 1),
#  ('My Favorite Martian', 1),
#  ('My Fellow Americans', 1),
#  ('My Girl', 1),
#  ('My Last Day Without You', 1),
#  ('My Life in Ruins', 1),
#  ('My Lucky Star', 1),
#  ('My Name Is Bruce', 1),
#  ('My Stepmother is an Alien', 1),
#  ('My Super Ex-Girlfriend', 1),
#  ('Mystery Men', 1),
#  ('Mystery, Alaska', 1),
#  ('Mystic Pizza', 1),
#  ('Nacho Libre', 1),
#  ('Nanny McPhee and the Big Bang', 1),
#  ('Nanny McPhee', 1),
#  ('Napoleon Dynamite', 1),
#  ('National Lampoons Loaded Weapon 1', 1),
#  ('National Lampoons Vacation', 1),
#  ('National Lampoon’s Van Wilder', 1),
#  ('Neal n Nikki', 1),
#  ('Neighbors 2: Sorority Rising', 1),
#  ('Neighbors', 1),
#  ('Never Again', 1),
#  ('New Years Eve', 1),
#  ('New York Minute', 1),
#  ('New York Stories', 1),
#  ('New in Town', 1),
#  ('Newlyweds', 1),
#  ('Next Day Air', 1),
#  ('Next Friday', 1),
#  ('Next Stop Wonderland', 1),
#  ('Nick and Norahs Infinite Playlist', 1),
#  ('Night at the Museum', 1),
#  ('Night at the Museum: Battle of the Smithsonian', 1),
#  ('Night at the Museum: Secret of the Tomb', 1),
#  ('Nims Island', 1),
#  ('No Reservations', 1),
#  ('No Strings Attached', 1),
#  ('Not Another Teen Movie', 1),
#  ('Not Cool', 1),
#  ...]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2: -0.2, 3:0, 4:0.5, 5:1}
score_weights = {1: 0.5, 2: 1, 3: 1.5, 4: 2, 5: 2.5} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = list(simple_recommender(movie))

        for similar_movie,i in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[i]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[i] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 5)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5098745327278761
# recall: 0.6069444444444445
# f1: 0.5278007637931525

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5218101745082048
# recall: 0.775
# f1: 0.6111717331664881

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5082124958856128
# recall: 0.8083333333333333
# f1: 0.6095686685002379

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, -1)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5106382978723404
# recall: 1.0
# f1: 0.676056338028169

# %% [markdown]
# Παρατηρούμε ότι αυξάνοντας το μέγεθος του training set που χρησιμοποιούμε, βελτιώνονται οι μετρικές ταξινόμησης. Συγκεκριμένα, σημαντική βελτίωση παρατηρείται στο recall, ενώ το precision παραμένει σχεδόν αμετάβλητο. Αυτό σημαίνει ότι σταδιακά πετυχαίνουμε περισσότερες από τις ταινίες που ενδιαφέρουν τον χρήστη. Συγχρόνως όμως, αυξάνονται και οι προτάσεις ταινιών οι οποίες δεν τον ενδιαφέρουν.

# %%
number_of_movies_list = [3, 5, 10, 30, 50, 75,-1]
metrics_dict = {}

for num_movies in number_of_movies_list:
    metrics = []
    for i in range(10):
        movie_score = train_recommender(train_ratings, rating_weights, score_weights, number_of_movies=num_movies)
        real, pred = predict_example(test_ratings, movie_score)
        metrics.append(get_metrics(real, pred))
    for metric in metrics[0].keys():
        if metric not in metrics_dict:
            metrics_dict[metric] = []
        metrics_dict[metric].append(np.mean([m[metric] for m in metrics]))
    
for metric, mean_value in metrics_dict.items():
    print(f"{metric}: {mean_value}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: [0.45895205524374455, 0.5239626757264004, 0.5059587860547078, 0.5097103692245086, 0.511543196198877, 0.5089583657118965, 0.5106382978723404]
# recall: [0.6124999999999999, 0.7069444444444445, 0.7638888888888888, 0.9236111111111113, 0.9833333333333334, 0.986111111111111, 1.0]
# f1: [0.5157799743778236, 0.5784910932134157, 0.5952154660030493, 0.6546721970643594, 0.6729678948646307, 0.671368998546013, 0.676056338028169]

# %%
total_mean_dict = {}
for metric, mean_values in metrics_dict.items():
    total_mean_dict[metric] = np.mean(mean_values)

for metric, total_mean in total_mean_dict.items():
    print(f"{metric}: {total_mean}")
# Out:
# precision: 0.5042462494332107
# recall: 0.8537698412698412
# f1: 0.6235074231567801
